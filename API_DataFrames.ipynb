# %%
import pandas as pd
import numpy as np
import ast

# %% [markdown]
# # Creando los dataframes para alimentar mis APIs

# %% [markdown]
# Debido a que cada dataframe es tan extenso, para eficientizar costos de deployment, elegí para alimentar mis APIs prepocesar los datos y preparar un CSV especifico para cada uno, de esta manera evito que en cada consulta se gasten recursos por demas.
#
# Tambien de esta manera reduje bastante el tamaño de cada DataFrame, pasando de mas de 600MB a solo 2MB en el mas extremo de los casos

# %%
df_games = pd.read_csv("data\df_games_clean.csv")
df_games.head(1)
# Out:
#                                               genres                title  \
# 0  ['Action', 'Casual', 'Indie', 'Simulation', 'S...  Lost Summoner Kitty
#
#                                                  url release_date  \
# 0  http://store.steampowered.com/app/761140/Lost_...   2018-01-04
#
#                                                 tags  \
# 0  ['Strategy', 'Action', 'Indie', 'Casual', 'Sim...
#
#                                          reviews_url              specs  \
# 0  http://steamcommunity.com/app/761140/reviews/?...  ['Single-player']
#
#    price  early_access        id  developer  \
# 0   4.99           0.0  761140.0  Kotoshiro
#
#                                            atributos
# 0  ['Casual', 'Strategy', 'Simulation', 'Indie', ...

# %%
df_items = pd.read_csv("data\df_items_clean.csv")
df_items.head(1)
# Out:
#    Unnamed: 0            user_id  items_count           steam_id  \
# 0           0  76561197970982479          277  76561197970982479
#
#                                             user_url  item_id       item_name  \
# 0  http://steamcommunity.com/profiles/76561197970...     10.0  Counter-Strike
#
#    playtime_forever  playtime_2weeks
# 0               6.0              0.0

# %%
df_reviews = pd.read_csv("data\df_reviews_clean.csv")
df_reviews.head(1)
# Out:
#              user_id                                           user_url  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
#
#        posted  item_id  recommend  sentimiento
# 0  2011-11-05   1250.0       True            2

# %% [markdown]
# ## 1° API: userdata

# %% [markdown]
# + **userdata( *`User_id` : str* )**:
#     Debe devolver `cantidad` de dinero gastado por el usuario, el `porcentaje` de recomendación en base a reviews.recommend y `cantidad de items`.

# %%
#creamos un dataframe con las columnas que necesito

user_data_id_price = pd.DataFrame({"item_id": df_games["id"], "price": df_games["price"]})

# %%
user_data_id_price
# Out:
#         item_id  price
# 0      761140.0   4.99
# 1      643980.0   0.00
# 2      670290.0   0.00
# 3      767400.0   0.99
# 4      773570.0   2.99
# ...         ...    ...
# 31819  773640.0   1.99
# 31820  733530.0   4.99
# 31821  610660.0   1.99
# 31822  658870.0   4.99
# 31823  681550.0   4.99
#
# [31824 rows x 2 columns]

# %%
#utilizo un dataframe auxiliar en donde joineo
df_aux = df_items.join(user_data_id_price.set_index('item_id'), on='item_id')

# %%
df_aux.head()
# Out:
#    Unnamed: 0            user_id  items_count           steam_id  \
# 0           0  76561197970982479          277  76561197970982479
# 1           1  76561197970982479          277  76561197970982479
# 2           2  76561197970982479          277  76561197970982479
# 3           3  76561197970982479          277  76561197970982479
# 4           4  76561197970982479          277  76561197970982479
#
#                                             user_url  item_id  \
# 0  http://steamcommunity.com/profiles/76561197970...     10.0
# 1  http://steamcommunity.com/profiles/76561197970...     20.0
# 2  http://steamcommunity.com/profiles/76561197970...     30.0
# 3  http://steamcommunity.com/profiles/76561197970...     40.0
# 4  http://steamcommunity.com/profiles/76561197970...     50.0
#
#                    item_name  playtime_forever  playtime_2weeks  price
# 0             Counter-Strike               6.0              0.0   9.99
# 1      Team Fortress Classic               0.0              0.0   4.99
# 2              Day of Defeat               7.0              0.0   4.99
# 3         Deathmatch Classic               0.0              0.0   4.99
# 4  Half-Life: Opposing Force               0.0              0.0   4.99

# %%
#elimino las columnas que no necesito que estaban en el dataframe df_items

user_data_id_price = df_aux.drop(columns= ['steam_id', 'user_url', 'playtime_forever', 'playtime_2weeks', 'Unnamed: 0', 'item_name','item_id'])

# %%
#agrupo por user_id

user_data = user_data_id_price.groupby('user_id').agg({'items_count': 'first', 'price': 'sum'}).reset_index()

# %%
#testeando
user_data
# Out:
#                  user_id  items_count    price
# 0                --000--           58   402.77
# 1                --ace--           44   166.82
# 2              --ionex--           23   109.92
# 3           -2SV-vuLB-Kg           68   437.49
# 4      -404PageNotFound-          149  1514.31
# ...                  ...          ...      ...
# 70907             zzonci            5    19.98
# 70908        zzoptimuszz           61    64.98
# 70909            zzydrax           13    99.94
# 70910              zzyfo           84   828.51
# 70911         zzzmidmiss           69   453.67
#
# [70912 rows x 3 columns]

# %%
#creo otro dataframe auxiliar ocn las columnas que necesito, user_id para joinear despues, recommend para sacar los datos.
df_aux2 = pd.DataFrame({"user_id": df_reviews["user_id"], "recommend": df_reviews["recommend"]})

# %%
#analizo porcentaje
df_aux2 = df_aux2.groupby('user_id')['recommend'].mean() * 100

# %%
df_aux2
# Out:
# user_id
# --000--         100.0
# --ace--         100.0
# --ionex--       100.0
# -2SV-vuLB-Kg    100.0
# -Azsael-        100.0
#                 ...
# zwanzigdrei     100.0
# zy0705          100.0
# zynxgameth      100.0
# zyr0n1c         100.0
# zzoptimuszz     100.0
# Name: recommend, Length: 25458, dtype: float64

# %%
df_aux2.to_frame()
# Out:
#               recommend
# user_id
# --000--           100.0
# --ace--           100.0
# --ionex--         100.0
# -2SV-vuLB-Kg      100.0
# -Azsael-          100.0
# ...                 ...
# zwanzigdrei       100.0
# zy0705            100.0
# zynxgameth        100.0
# zyr0n1c           100.0
# zzoptimuszz       100.0
#
# [25458 rows x 1 columns]

# %%
df_aux2.reset_index()
# Out:
#             user_id  recommend
# 0           --000--      100.0
# 1           --ace--      100.0
# 2         --ionex--      100.0
# 3      -2SV-vuLB-Kg      100.0
# 4          -Azsael-      100.0
# ...             ...        ...
# 25453   zwanzigdrei      100.0
# 25454        zy0705      100.0
# 25455    zynxgameth      100.0
# 25456       zyr0n1c      100.0
# 25457   zzoptimuszz      100.0
#
# [25458 rows x 2 columns]

# %%
#joineo user_data con el dataframe auxiliar
user_data = user_data.join(df_aux2, on='user_id')

# %%
user_data["recommend"] = user_data["recommend"].fillna("Sin Recomendaciones")

# %%
#todo anda bien. tengo en un solo datadframe el total de los datos que necesito para las consultas de la API. 
user_data
# Out:
#                  user_id  items_count    price            recommend
# 0                --000--           58   402.77                100.0
# 1                --ace--           44   166.82                100.0
# 2              --ionex--           23   109.92                100.0
# 3           -2SV-vuLB-Kg           68   437.49                100.0
# 4      -404PageNotFound-          149  1514.31  Sin Recomendaciones
# ...                  ...          ...      ...                  ...
# 70907             zzonci            5    19.98  Sin Recomendaciones
# 70908        zzoptimuszz           61    64.98                100.0
# 70909            zzydrax           13    99.94  Sin Recomendaciones
# 70910              zzyfo           84   828.51  Sin Recomendaciones
# 70911         zzzmidmiss           69   453.67  Sin Recomendaciones
#
# [70912 rows x 4 columns]

# %%
#user_data.to_csv('user_data.csv')

# %% [markdown]
# ## 2° API: countreviews

# %% [markdown]
# **countreviews( *`YYYY-MM-DD` y `YYYY-MM-DD` : str* )**:
#     `Cantidad de usuarios` que realizaron reviews entre las fechas dadas y, el `porcentaje` de recomendación de los mismos en base a reviews.recommend.

# %%
#creo un dataframe con las columnas que necesito del df_reviews
countreviews = pd.DataFrame({"review": df_reviews["user_id"], "posted": df_reviews["posted"], "recommend": df_reviews["recommend"]})

# %%
#review 1 es por que no me interesa el usuario especifico, si no que me interesa sumarlo
countreviews['review'] = 1

# %%
#agrupo por fecha, recomend va a ser por 

countreviews = countreviews.groupby('posted').agg(
    recommend_percentage=('recommend', lambda x: (x.sum() / len(x)) * 100),
    sum_review=('review', 'sum')
).reset_index()

# %%
#2015-12-31 / 2010-10-16  rari pero bueno.
#listo mi dataframe para responder consultas
countreviews
# Out:
#           posted  recommend_percentage  sum_review
# 0     2010-10-16            100.000000           1
# 1     2010-10-25            100.000000           1
# 2     2010-11-19            100.000000           1
# 3     2010-11-20            100.000000           2
# 4     2010-11-22            100.000000           3
# ...          ...                   ...         ...
# 1639  2015-12-27             88.235294          85
# 1640  2015-12-28             89.247312          93
# 1641  2015-12-29             87.012987          77
# 1642  2015-12-30             84.000000          75
# 1643  2015-12-31             92.105263          76
#
# [1644 rows x 3 columns]

# %%
countreviews["posted"] = pd.to_datetime(countreviews["posted"])

# %%
countreviews.dtypes
# Out:
# posted                  datetime64[ns]
# recommend_percentage           float64
# sum_review                       int64
# dtype: object

# %%
#countreviews.to_csv("count_reviews.csv")

# %% [markdown]
# ## 3° API: genre

# %% [markdown]
# **genre( *`género` : str* )**:
#     Devuelve el `puesto` en el que se encuentra un género sobre el ranking de los mismos analizado bajo la columna PlayTimeForever.

# %%
#primero creo los dataframes que voy a utilizar para hacer el dataframe final para la consulta
df_aux1 = pd.DataFrame({"genres" : df_games["genres"], "item_id" : df_games["id"]})
df_aux2 = pd.DataFrame({"item_id": df_items["item_id"], "playtime_forever": df_items["playtime_forever"]})

# %%
#joineo
genre = df_aux2.join(df_aux1.set_index('item_id'), on= 'item_id')

# %%
#borro los Nan por que me estaban dando problemas con la libreria ast.
genre = genre.dropna(subset=['genres'])

genre['genres'] = genre['genres'].apply(ast.literal_eval)

# %%
#cambio el tipo de datos para que pese menos y no haya posibilidad de error
genre["playtime_forever"] = genre["playtime_forever"].astype('int32')

# %%
#desanido la columna de genre, debido a que los juegos pueden ser que tengas mas de un genero. Tambien elimino la columna "item_id"
genre = genre.explode('genres')
genre.drop(columns=['item_id'])
# Out:
#          playtime_forever        genres
# 0                       6        Action
# 1                       0        Action
# 2                       7        Action
# 3                       0        Action
# 4                       0        Action
# ...                   ...           ...
# 5153206                 3     Adventure
# 5153206                 3  Free to Play
# 5153207                 4        Casual
# 5153207                 4  Free to Play
# 5153207                 4         Indie
#
# [10074829 rows x 2 columns]

# %%
#agrupo por genero y sumo los playtimes
genre = genre.groupby('genres')['playtime_forever'].sum()

# %%
#testeando
genre.to_frame()
genre.reset_index()
genre = pd.DataFrame(genre)

# %%
genre = genre.sort_values(by="playtime_forever", ascending=False)

# %%
top = []
for i in range(1,22):
    top.append(f"Top {i}")

# %%
genre["Top"] = top

# %%
#genre.to_csv("genre.csv")

# %% [markdown]
# ## 4° API: userforgenre

# %% [markdown]
# **userforgenre( *`género` : str* )**:
#     `Top 5` de usuarios con más horas de juego en el género dado, con su URL y user_id.

# %%
#creo dataframes auxiliares con las columnas que voy a utilizar
df_aux1 = pd.DataFrame({"genres" : df_games["genres"], "item_id" : df_games["id"]})
df_aux2 = pd.DataFrame({"item_id": df_items["item_id"], "playtime_forever": df_items["playtime_forever"], 'user_url' : df_items['user_url'], 'user_id' : df_items["user_id"]})

# %%
df_aux1 = df_aux1.dropna(subset= 'genres')
df_aux1['genres'] = df_aux1['genres'].apply(ast.literal_eval)
df_aux1 = df_aux1.explode("genres")

# %%
df_aux1
# Out:
#            genres   item_id
# 0          Action  761140.0
# 0          Casual  761140.0
# 0           Indie  761140.0
# 0      Simulation  761140.0
# 0        Strategy  761140.0
# ...           ...       ...
# 31821      Racing  610660.0
# 31821  Simulation  610660.0
# 31822      Casual  658870.0
# 31822       Indie  658870.0
# 31823         NaN  681550.0
#
# [74152 rows x 2 columns]

# %%
userforgenre = df_aux2.join(df_aux1.set_index('item_id'), on= 'item_id')
userforgenre["playtime_forever"] = userforgenre["playtime_forever"].astype('int32')
userforgenre = userforgenre.drop(columns= 'item_id')

# %%
#despues de joinear asi es como queda, podria dejarlo así pero se puede procesar mas aún
userforgenre
# Out:
#          playtime_forever                                           user_url  \
# 0                       6  http://steamcommunity.com/profiles/76561197970...
# 1                       0  http://steamcommunity.com/profiles/76561197970...
# 2                       7  http://steamcommunity.com/profiles/76561197970...
# 3                       0  http://steamcommunity.com/profiles/76561197970...
# 4                       0  http://steamcommunity.com/profiles/76561197970...
# ...                   ...                                                ...
# 5153206                 3  http://steamcommunity.com/profiles/76561198329...
# 5153207                 4  http://steamcommunity.com/profiles/76561198329...
# 5153207                 4  http://steamcommunity.com/profiles/76561198329...
# 5153207                 4  http://steamcommunity.com/profiles/76561198329...
# 5153208                 3  http://steamcommunity.com/profiles/76561198329...
#
#                    user_id        genres
# 0        76561197970982479        Action
# 1        76561197970982479        Action
# 2        76561197970982479        Action
# 3        76561197970982479        Action
# 4        76561197970982479        Action
# ...                    ...           ...
# 5153206  76561198329548331  Free to Play
# 5153207  76561198329548331        Casual
# 5153207  76561198329548331  Free to Play
# 5153207  76561198329548331         Indie
# 5153208  76561198329548331           NaN
#
# [10939058 rows x 4 columns]

# %%
userforgenre = userforgenre.groupby(['user_url', 'user_id', 'genres'], as_index=False)['playtime_forever'].sum()

# %% [markdown]
# Es posbile procesarla mas aún a este dataframe dadas las caracteristicas de la peticion. Unicamente tengo que almacenar 5 registros por genero, lo cual reduciría considerablemente el consumo de procesamiento y el tamaño del csv, sin embargo los tiempos de espera son  mas que aceptables y la cantidad de procesamiento tambien. Por ahora no lo veo necesario

# %%
userforgenre.head(20)
# Out:
#                                 user_url  user_id                 genres  \
# 0   http://steamcommunity.com/id/--000--  --000--                 Action
# 1   http://steamcommunity.com/id/--000--  --000--              Adventure
# 2   http://steamcommunity.com/id/--000--  --000--                 Casual
# 3   http://steamcommunity.com/id/--000--  --000--           Early Access
# 4   http://steamcommunity.com/id/--000--  --000--           Free to Play
# 5   http://steamcommunity.com/id/--000--  --000--                  Indie
# 6   http://steamcommunity.com/id/--000--  --000--  Massively Multiplayer
# 7   http://steamcommunity.com/id/--000--  --000--                    RPG
# 8   http://steamcommunity.com/id/--000--  --000--             Simulation
# 9   http://steamcommunity.com/id/--000--  --000--                 Sports
# 10  http://steamcommunity.com/id/--000--  --000--               Strategy
# 11  http://steamcommunity.com/id/--ace--  --ace--                 Action
# 12  http://steamcommunity.com/id/--ace--  --ace--              Adventure
# 13  http://steamcommunity.com/id/--ace--  --ace--                 Casual
# 14  http://steamcommunity.com/id/--ace--  --ace--           Free to Play
# 15  http://steamcommunity.com/id/--ace--  --ace--                  Indie
# 16  http://steamcommunity.com/id/--ace--  --ace--  Massively Multiplayer
# 17  http://steamcommunity.com/id/--ace--  --ace--                    RPG
# 18  http://steamcommunity.com/id/--ace--  --ace--                 Racing
# 19  http://steamcommunity.com/id/--ace--  --ace--             Simulation
#
#     playtime_forever
# 0             139469
# 1              11722
# 2              16135
# 3                531
# 4              20448
# 5              12218
# 6              12788
# 7               7362
# 8               1248
# 9               5963
# 10               656
# 11             69325
# 12              4861
# 13              3775
# 14              5322
# 15              5466
# 16                 0
# 17              1335
# 18                 6
# 19               334

# %%
#userforgenre.to_csv("userforgenre.csv")

# %% [markdown]
# ## 5° API: developer

# %% [markdown]
# **developer( *`desarrollador` : str* )**:
#     `Cantidad` de items y `porcentaje` de contenido Free por año según empresa desarrolladora.

# %%
#creo mi df nuevo con las columnas que voy a necesitar
developer = pd.DataFrame({"developer": df_games["developer"],"release_date": df_games["release_date"], "price": df_games["price"]})

# %%
#reemplazamos los "NoData" por NaN asi puedo utilizar funciones para cambiar a datetime
developer["release_date"] = developer["release_date"].replace("NoData", np.nan)

# %%
#reemplazo todos las fecha por su año unicamente
developer['release_date'] = pd.to_datetime(developer['release_date'])
developer['release_date'] = developer['release_date'].dt.year

# %%
developer = developer.groupby(['developer', 'release_date'])['price'].apply(lambda x: (x == 0).mean()).reset_index()

# %%
#testeando
developer.query("developer == 'Gogii Games'")
# Out:
#         developer  release_date  price
# 5326  Gogii Games        2007.0    0.0
# 5327  Gogii Games        2008.0    0.0
# 5328  Gogii Games        2010.0    0.0
# 5329  Gogii Games        2012.0    0.0
# 5330  Gogii Games        2014.0    0.0

# %%
developer["release_date"] = developer["release_date"].astype("int16")
developer.rename(columns={"price": 'porcentaje'})
#developer.to_csv("developer.csv")
# Out:
#                 developer  release_date  porcentaje
# 0             +7 Software          2016         0.0
# 1      +Mpact Games, LLC.          2017         0.0
# 2                 .M.Y.W.          2016         0.0
# 3               .ez Games          2017         0.0
# 4          07th Expansion          2015         0.0
# ...                   ...           ...         ...
# 14850                萌石游戏          2017         0.0
# 14851             高考恋爱委员会          2015         1.0
# 14852        高考恋爱委员会,Days          2015         0.0
# 14853         高考恋爱委员会,橘子班          2015         0.0
# 14854         高考恋爱委员会,橘子班          2017         0.0
#
# [14855 rows x 3 columns]

# %% [markdown]
# ## 6° API: sentiment_analysis

# %% [markdown]
# **sentiment_analysis( *`empresa desarrolladora` : str* )**:
#     Según el año de lanzamiento, se devuelve una lista con la cantidad de registros de reseñas de usuarios que se encuentren categorizados con un análisis de sentimiento.
#
#
#
#
# <br/>

# %%
#creamos el primer df que vamos a usar
df_aux = pd.DataFrame({"release_date": df_games["release_date"],"item_id" : df_games["id"]})

# %%
#reemplazamos los "NoData" por NaN asi puedo utilizar funciones para cambiar a datetime
df_aux["release_date"] = df_aux["release_date"].replace("NoData", np.nan) 
df_aux['release_date'] = pd.to_datetime(df_aux['release_date'])
df_aux['release_date'] = df_aux['release_date'].dt.year

# %%
df_aux
# Out:
#        release_date   item_id
# 0            2018.0  761140.0
# 1            2018.0  643980.0
# 2            2017.0  670290.0
# 3            2017.0  767400.0
# 4               NaN  773570.0
# ...             ...       ...
# 31819        2018.0  773640.0
# 31820        2018.0  733530.0
# 31821        2018.0  610660.0
# 31822        2017.0  658870.0
# 31823           NaN  681550.0
#
# [31824 rows x 2 columns]

# %%
#creamos el segundo df que vamos a usar
df_aux2 = pd.DataFrame({"sentimiento" : df_reviews["sentimiento"], "item_id" : df_reviews["item_id"]})

# %%
df_aux2
# Out:
#        sentimiento   item_id
# 0                2    1250.0
# 1                2   22200.0
# 2                2   43110.0
# 3                2  251610.0
# 4                2  227300.0
# ...            ...       ...
# 59300            2      70.0
# 59301            2  362890.0
# 59302            2  273110.0
# 59303            2     730.0
# 59304            2     440.0
#
# [59305 rows x 2 columns]

# %%
#hacemos la agrupacion por item_id
df_aux2 = df_aux2.groupby('item_id')['sentimiento'].value_counts().unstack(fill_value=0)

# %%
#eureka
df_aux2
# Out:
# sentimiento  0   1   2
# item_id
# 10.0         1  23  33
# 20.0         2   5  10
# 30.0         0   1   3
# 40.0         0   0   1
# 50.0         0   1   3
# ...         ..  ..  ..
# 521340.0     0   0   2
# 521430.0     0   0   1
# 521570.0     2   0   0
# 521990.0     0   0   1
# 527340.0     0   1   0
#
# [3682 rows x 3 columns]

# %%
#hago un join por "item_id"
sentiment_analysis = df_aux2.join(df_aux.set_index('item_id'), on='item_id')

# %%
sentiment_analysis
# Out:
#           0   1   2  release_date
# item_id
# 10.0      1  23  33        2000.0
# 20.0      2   5  10        1999.0
# 30.0      0   1   3        2003.0
# 40.0      0   0   1        2001.0
# 50.0      0   1   3        1999.0
# ...      ..  ..  ..           ...
# 521340.0  0   0   2        2016.0
# 521430.0  0   0   1        2016.0
# 521570.0  2   0   0        2016.0
# 521990.0  0   0   1        2016.0
# 527340.0  0   1   0        2016.0
#
# [3682 rows x 4 columns]

# %%
sentiment_analysis.set_index('release_date', inplace=True)  # Establecer 'release_date' como índice
sentiment_analysis = sentiment_analysis.groupby('release_date').sum() #agrupo por año

# %%
sentiment_analysis
# Out:
#                  0     1     2
# release_date
# 1989.0           0     0     1
# 1990.0           1     0     4
# 1991.0           0     0     1
# 1992.0           1     0     2
# 1993.0           1     1     3
# 1994.0           3     4     8
# 1995.0           5     1    10
# 1996.0           0     3     5
# 1997.0           8     7    33
# 1998.0          14    19    63
# 1999.0          14    21    41
# 2000.0           8    35    56
# 2001.0          10     5    20
# 2002.0           7     7    31
# 2003.0          47    56   114
# 2004.0          60   143   347
# 2005.0          34    72   188
# 2006.0         220   514  1330
# 2007.0         374  1110  2690
# 2008.0          59    93   308
# 2009.0         299   506  1171
# 2010.0         284   417  1309
# 2011.0         436   804  2214
# 2012.0        1310  2224  5521
# 2013.0        1156  1651  4778
# 2014.0        1117  1399  3930
# 2015.0        1164  1521  4048
# 2016.0         499   595  1903
# 2017.0         335   483  1286

# %%
#sentiment_analysis.to_csv('sentiment_analysis.csv')

# %% [markdown]
# ## 7° API: recomend (modelo de ML)

# %% [markdown]
# **recomend( *`id_del_producto` : int* )**:
#     Recomienda un juego en base al id del juego brindado.
# <br/>

# %% [markdown]
# #### Analisis exploratorio para para modelado.

# %% [markdown]
# Para crear mi modelo de machine learning primero voy a realizar un pequeño EDA orientado para comprender el contenido de mis datos y asegurar que no hayan interferencias futuras. Este modelo se va a bazar en en unicamente 2 dataframes:
#
# - df_reviews
# - df_games

# %% [markdown]
# #### Data Frame REVIEWS

# %%
#Vemos el tamaño de nuestro DF
df_reviews.shape
# Out:
# (59305, 6)

# %%
#hacemos un sampleo aleatorio para ver como esta estructurada nuestra informacion
df_reviews.sample(5)
# Out:
#                  user_id                                           user_url  \
# 8779   76561198009000573  http://steamcommunity.com/profiles/76561198009...
# 38041  76561198073259913  http://steamcommunity.com/profiles/76561198073...
# 44790       jujubamagica          http://steamcommunity.com/id/jujubamagica
# 2104   76561198026040814  http://steamcommunity.com/profiles/76561198026...
# 1499            Clouwolf              http://steamcommunity.com/id/Clouwolf
#
#            posted   item_id  recommend  sentimiento
# 8779          NaN  381210.0      False            0
# 38041  2015-07-12  274940.0       True            1
# 44790  2014-08-18     550.0       True            1
# 2104   2015-11-26  211420.0       True            0
# 1499          NaN     730.0      False            2

# %%
#nombres de las columnas
df_reviews.columns
# Out:
# Index(['user_id', 'user_url', 'posted', 'item_id', 'recommend', 'sentimiento'], dtype='object')

# %%
#posted deveria ser un datetime, no un object
df_reviews.dtypes
# Out:
# user_id         object
# user_url        object
# posted          object
# item_id        float64
# recommend         bool
# sentimiento      int64
# dtype: object

# %% [markdown]
# ### Preparacion de Datos

# %%
df_reviews["posted"] = pd.to_datetime(df_reviews["posted"])

# %%
df_reviews.dtypes
# Out:
# user_id                object
# user_url               object
# posted         datetime64[ns]
# item_id               float64
# recommend                bool
# sentimiento             int64
# dtype: object

# %%
#encontramos algo similar con respecto al df anterior, user_id y user_url son referenciales a lo mismo. Por ahora los vamos a dejar.
df_reviews.sample(3)
# Out:
#                  user_id                                           user_url  \
# 21122  76561198018469813  http://steamcommunity.com/profiles/76561198018...
# 870             Aurora99              http://steamcommunity.com/id/Aurora99
# 31389  ultimatefaggotwow     http://steamcommunity.com/id/ultimatefaggotwow
#
#           posted   item_id  recommend  sentimiento
# 21122 2014-01-26     440.0       True            2
# 870   2014-09-15   72850.0       True            1
# 31389 2014-01-31  204300.0       True            1

# %%
#intentando identificar si aun tenemos valores faltantes. 
df_reviews.isna().sum()
# Out:
# user_id            0
# user_url           0
# posted         10119
# item_id            0
# recommend          0
# sentimiento        0
# dtype: int64

# %% [markdown]
# Los nulos constituyen casi un 20% del total de los datos de la columna de fecha, lo cual dificulta un poco el analisis.
# En este caso voy a eliminar la columna ya que no la necesito para hacer mi modelado y no me va a aportar un valor significativo.
# Si en vez de eliminar la columna, elimino las filas que contienen nulos, me quedo con los datos de la fecha que fuero posteados pero pierdo mucha informacion valiosa sobre todo en la columna recommend y sentimiento

# %%
df_reviews.drop(columns=['posted'], inplace= True)

# %%
df_reviews.sample(3)
# Out:
#                  user_id                                           user_url  \
# 39820        geekosaurus           http://steamcommunity.com/id/geekosaurus
# 42352           ToxicK-9              http://steamcommunity.com/id/ToxicK-9
# 47906  76561198045627858  http://steamcommunity.com/profiles/76561198045...
#
#         item_id  recommend  sentimiento
# 39820  363970.0       True            0
# 42352     550.0       True            0
# 47906  372000.0      False            1

# %% [markdown]
# ## Data Frame GAMES

# %%
#Vemos el tamaño de nuestro DF
df_games.shape
# Out:
# (31824, 12)

# %%
#hacemos un sampleo aleatorio para ver como esta estructurada nuestra informacion
df_games.sample(5)
# Out:
#                                            genres  \
# 3521   ['Action', 'Adventure', 'Indie', 'Racing']
# 3658            ['Action', 'Indie', 'Simulation']
# 10331       ['Adventure', 'Casual', 'Simulation']
# 29289          ['Adventure', 'RPG', 'Simulation']
# 19689                      ['Adventure', 'Indie']
#
#                                                    title  \
# 3521                            JumpJet Rex - Soundtrack
# 3658                              Luna's Wandering Stars
# 10331  Libra of the Vampire Princess: Lycoris &amp; A...
# 29289  Starlite: Astronaut Rescue - Developed in Coll...
# 19689                                  Behind the Memory
#
#                                                      url release_date  \
# 3521   http://store.steampowered.com/app/364400/JumpJ...   2015-04-21
# 3658   http://store.steampowered.com/app/330660/Lunas...   2015-05-15
# 10331  http://store.steampowered.com/app/644680/Libra...   2017-07-07
# 29289  http://store.steampowered.com/app/266090/Starl...   2014-01-27
# 19689  http://store.steampowered.com/app/568340/Behin...   2016-11-25
#
#                                                     tags  \
# 3521          ['Action', 'Adventure', 'Indie', 'Racing']
# 3658   ['Simulation', 'Action', 'Indie', 'Puzzle', 'L...
# 10331  ['Adventure', 'Casual', 'Simulation', 'Visual ...
# 29289  ['Adventure', 'RPG', 'Simulation', 'Space', 'S...
# 19689        ['Adventure', 'Indie', 'Walking Simulator']
#
#                                              reviews_url  \
# 3521   http://steamcommunity.com/app/364400/reviews/?...
# 3658   http://steamcommunity.com/app/330660/reviews/?...
# 10331  http://steamcommunity.com/app/644680/reviews/?...
# 29289  http://steamcommunity.com/app/266090/reviews/?...
# 19689  http://steamcommunity.com/app/568340/reviews/?...
#
#                                                    specs  price  early_access  \
# 3521   ['Single-player', 'Shared/Split Screen', 'Down...   3.99           0.0
# 3658   ['Single-player', 'Steam Achievements', 'Steam...   9.99           0.0
# 10331                                  ['Single-player']  15.99           0.0
# 29289                                  ['Single-player']   2.99           0.0
# 19689  ['Single-player', 'Steam Achievements', 'Steam...   3.99           0.0
#
#              id                       developer  \
# 3521   364400.0              TreeFortress Games
# 3658   330660.0                  Serenity Forge
# 10331  644680.0        onomatope*,MiKandi Japan
# 29289  266090.0  Project Whitecard Studios Inc.
# 19689  568340.0                        GuraShop
#
#                                                atributos
# 3521   ['Racing', 'Adventure', 'Stats', 'Full control...
# 3658   ['Space', 'Level Editor', 'Great Soundtrack', ...
# 10331  ['Casual', 'Anime', 'Adventure', 'Simulation',...
# 29289  ['Space', 'Adventure', 'Short', 'Simulation', ...
# 19689  ['Partial Controller Support', 'Walking Simula...

# %%
#id refiere a item_id.
#tambien tenemos la columna que cree antes de atributos con la union de genres, specs y tags.

df_games.columns
# Out:
# Index(['genres', 'title', 'url', 'release_date', 'tags', 'reviews_url',
#        'specs', 'price', 'early_access', 'id', 'developer', 'atributos'],
#       dtype='object')

# %% [markdown]
# #### Preparacion de Datos

# %%
#voy a eliminar las columnas de specs, genres y tags para hacer el modelado ya que para mi modelado solo voy a usar mi columna atributos

df_games.rename(columns= {'id' : "item_id"}, inplace=True)
df_games.drop(columns=["genres","tags","specs"], inplace=True)

# %%
#Hay que acomodar algunos tipos de datos como "early_access", "release_date" y transformar a dummies "atributos"
df_games.dtypes
# Out:
# title            object
# url              object
# release_date     object
# reviews_url      object
# price           float64
# early_access    float64
# item_id         float64
# developer        object
# atributos        object
# dtype: object

# %%
df_games['release_date'] = df_games['release_date'].replace("NoData", np.nan)
df_games['release_date'] = pd.to_datetime(df_games['release_date'])
df_games["early_access"] = df_games["early_access"].astype(bool)
df_games['atributos'] = df_games['atributos'].apply(ast.literal_eval)

# %%
df_games.dtypes
# Out:
# title                   object
# url                     object
# release_date    datetime64[ns]
# reviews_url             object
# price                  float64
# early_access              bool
# item_id                float64
# developer               object
# atributos               object
# dtype: object

# %%
#aislo las columnas mas reelevantes de cada DF. Decido hacer un modelo de recomendacion basado en los tags de los juegos por lo que no voy a utilizar ahora el df_items
df_games.drop(columns=["url","release_date","reviews_url","early_access"],inplace=True)
df_reviews.drop(columns=["user_url","user_id",], inplace=True)

# %%
#juegos con mas recomendaciones
df_reviews = df_reviews.replace({True: 1, False:-1}).groupby('item_id').agg({'recommend': 'sum', 'sentimiento': 'mean'}).reset_index()

# %%
df_reviews
# Out:
#        item_id  recommend  sentimiento
# 0         10.0         55     1.561404
# 1         20.0          5     1.470588
# 2         30.0          2     1.750000
# 3         40.0          1     2.000000
# 4         50.0          2     1.750000
# ...        ...        ...          ...
# 3677  521340.0          2     2.000000
# 3678  521430.0          1     2.000000
# 3679  521570.0          2     0.000000
# 3680  521990.0          1     2.000000
# 3681  527340.0          1     1.000000
#
# [3682 rows x 3 columns]

# %%
#voy a crear un indice entre recommend y sentimineto.
df_reviews['score'] = df_reviews['recommend'] / df_reviews['recommend'].max() + df_reviews['sentimiento'] / df_reviews['sentimiento'].max()
df_reviews['score'] = (df_reviews['score'] - df_reviews['score'].min()) / (df_reviews['score'].max() - df_reviews['score'].min())
df_reviews.drop(columns=["recommend", "sentimiento"], inplace=True)

# %%
df_reviews
# Out:
#        item_id     score
# 0         10.0  0.446625
# 1         20.0  0.413156
# 2         30.0  0.490929
# 3         40.0  0.560787
# 4         50.0  0.490929
# ...        ...       ...
# 3677  521340.0  0.560947
# 3678  521430.0  0.560787
# 3679  521570.0  0.000803
# 3680  521990.0  0.560787
# 3681  527340.0  0.280715
#
# [3682 rows x 2 columns]

# %%
#elimino espacios de cada uno de los atributos y las columnas que ya no necesito
df_games["atributos"] = df_games["atributos"].apply(lambda x:[i.replace(" ","") for i in x])
df_games["atributos"] = df_games["atributos"].apply(lambda x: ', '.join(map(str, x)))
df_games["tags"] = df_games["atributos"]+df_games["price"].astype(str)+df_games["developer"]
df_games.drop(columns=["atributos","developer","price"], inplace=True)
df_games["tags"] = df_games["tags"].apply(lambda x: x.lower())

# %%
df_games
# Out:
#                           title   item_id  \
# 0           Lost Summoner Kitty  761140.0
# 1                     Ironbound  643980.0
# 2       Real Pool 3D - Poolians  670290.0
# 3                       弹炸人2222  767400.0
# 4                 Log Challenge  773570.0
# ...                         ...       ...
# 31819            Colony On Mars  773640.0
# 31820  LOGistICAL: South Africa  733530.0
# 31821             Russian Roads  610660.0
# 31822       EXIT 2 - Directions  658870.0
# 31823               Maze Run VR  681550.0
#
#                                                     tags
# 0      casual, strategy, simulation, indie, single-pl...
# 1      pvp, replayvalue, charactercustomization, fant...
# 2      casual, stats, simulation, indie, single-playe...
# 3       adventure, action, single-player, casual0.99彼岸领域
# 4      casual, trackedmotioncontrollers, htcvive, ful...
# ...                                                  ...
# 31819  casual, strategy, simulation, indie, single-pl...
# 31820  casual, stats, strategy, indie, single-player,...
# 31821  racing, steamtradingcards, simulation, indie, ...
# 31822  casual, indie, single-player, steamachievement...
# 31823  standing, vr, earlyaccess, htcvive, stats, tra...
#
# [31824 rows x 3 columns]

# %%
df_itemsxitems = pd.merge(df_games, df_reviews, on="item_id", how="outer")
df_itemsxitems = df_itemsxitems.dropna(subset="title").fillna(0).sort_values(by="score", ascending=False)

# %%
df_itemsxitems
# Out:
#                                    title   item_id  \
# 31577                    Team Fortress 2     440.0
# 1034    Counter-Strike: Global Offensive     730.0
# 53                           Garry's Mod    4000.0
# 1451                              Dota 2     570.0
# 30979                           Terraria  105600.0
# ...                                  ...       ...
# 11458                          Toradora!  694620.0
# 11457                          Celtabula  706200.0
# 11456  TANE DLC: Orient Express Trainset  715080.0
# 11455                       PetriDish.pw  688730.0
# 31823                        Maze Run VR  681550.0
#
#                                                     tags     score
# 31577  robots, class-based, stats, fps, first-person,...  1.000000
# 1034   pvp, stats, fps, realistic, difficult, first-p...  0.921146
# 53     animation&modeling, fps, steamcloud, first-per...  0.698078
# 1451   pvp, replayvalue, charactercustomization, htcv...  0.630267
# 30979  replayvalue, onlineco-op, onlinemulti-player, ...  0.564298
# ...                                                  ...       ...
# 11458                          episodic, anime0.99nodata  0.000000
# 11457     casual, puzzle, single-player, indie1.99skip32  0.000000
# 11456  simulation, co-op, single-player, multi-player...  0.000000
# 11455  casual, partialcontrollersupport, massivelymul...  0.000000
# 31823  standing, vr, earlyaccess, htcvive, stats, tra...  0.000000
#
# [31824 rows x 4 columns]

# %%
#exporto mis datos en un archivo csv.
df_itemsxitems.to_csv("datos_ML.csv")
df_itemsxitems.head(2000).to_csv("datos_ML_reduced.csv")
